# %%
# !pip install python-pptx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting python-pptx
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: Pillow>=3.3.2 in c:\programdata\anaconda3\lib\site-packages (from python-pptx) (10.3.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx)
#   Downloading XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: lxml>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from python-pptx) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\programdata\anaconda3\lib\site-packages (from python-pptx) (4.11.0)
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
# Downloading XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
# Installing collected packages: XlsxWriter, python-pptx
# Successfully installed XlsxWriter-3.2.0 python-pptx-1.0.2

# %%
from pptx import Presentation

def extract_text_from_pptx(pptx_file):
    # Load the PowerPoint file
    presentation = Presentation(pptx_file)
    
    # Initialize an empty list to store the text
    all_text = []
    
    # Loop through each slide
    for slide in presentation.slides:
        for shape in slide.shapes:
            if hasattr(shape, "text"):  # Check if the shape has text
                all_text.append(shape.text)
    
    return "\n".join(all_text)

# Example usage
pptx_file = "Downloads/Dimcon-OracleEPM.pptx"
text_content = extract_text_from_pptx(pptx_file)
print(text_content)
# Out:
# ORACLE EPM
# Optimize Your Enterprise Performance with Dimcon
# 2023 – Dimcon
# Discover What Lies Within
# OUR STORY
# LEADERSHIP
# INDUSTRIES WE CATER TO
# ENTERPRISE CLOUD APPLICATIONS
# SERVICES
# OUR HIGH LEVEL PROCESS
# SERVICE PILLARS
# OUR CLIENTS
# UNIQUE ADVANTAGES
# SAFETY AND SECURITY
# WHY DIMCON
# GEOGRAPHIC PRESENCE
# CONTACT US
#
#
# 02
# 2023 – Dimcon
#
#
#
#
#
#
# At DIMCON, we are thrilled to offer our exceptional services to Oracle EPM (Enterprise Performance Management). Our dedicated team of highly skilled professionals takes immense pride in delivering exceptional results by enhancing the functionality, performance, and quality of your Oracle EPM application
# The R﻿emarkable Tale of DIMCON
#
# 03
# 2023 – Dimcon
#
#
#
# Naga Nandigum
# Pavan Ravula
# Subba Arumilli
# President and CEO
# CTO
# Mentor
# Expert in ERP and cloud implementation. Streamlines processes and ensures compliance for optimized productivity.
# Seasoned expert in the EPM industry, with extensive experience in leading successful teams and delivering innovative solutions to clients.
# IT entrepreneur with a results-driven approach. Builds strong client relationships and launches profitable initiatives.
#
# 04
# 2023 – Dimcon
#
# Innovaters-In- Chief
#
#
#
#
#
# Geographic Presence
#
#
# 05
# 2023 – Dimcon
#
#
#
# Service Introduction
# DIMCON's Oracle EPM (Enterprise Performance Management) services are designed to optimize your financial workflows and elevate the performance of your system. With our in-depth knowledge of Oracle EPM, we provide tailored recommendations to enhance the efficiency and effectiveness of your financial processes.
#
# 06
# 2023 – Dimcon
#
#
#
#
#
#
#
#
#
#
#
# Explore the Service Landscape: Classification Insights
# Financial Consolidation And Close Cloud Service
# Planning and Budgeting Cloud Service
# Narrative Reporting
# Account Reconciliation Cloud Service
# 07
# 2023 – Dimcon
# Oracle EPM (Enterprise Performance Management) services can be classified into several categories based on the specific areas they address within the EPM landscape. Here are some common classifications:
#
#
# Implementing and managing Oracle EPM (Enterprise Performance Management) solutions can come with various challenges. Some common challenges organizations may face include:
#
#
#
#
#
#
#
#
#
#
#
# Fueling Innovation:
# Rising Above Challenges
# Keeping Pace with Technology Advancements
# Performance Optimization
# Complex Implementation
# Ongoing Support and Maintenance
# Data Integration and Quality
# Customization and Scalability
# Change Management and User Adoption
# 08
# 2023 – Dimcon
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Key Features and Benefits
# of Our Service Offerings
# Here are some of the key features and benefits of Oracle EPM:
# Cloud-based Deployment and Security
# Integrated Performance Management
# Consolidation and Reporting
# Workflow Automation and Collaboration
# Data Integration and Data Quality Management
# Performance Scorecards and KPI Monitoring
# Robust Financial Planning and Analysis
# Scalability and Performance Optimization
# 09
# 2023 – Dimcon
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ensuring the safety and security of our clients' financial information is a top priority for us
# Technologies Used
# Encryption
# Two-Factor Authentication
# Fraud Detection Systems
# Firewalls
# Physical Security
# Regular Software Updates
# Employee Training
#
#
# 10
# 2023 – Dimcon
#
# Here is a general overview of the Oracle Cloud HCM implementation process:
#
# Navigating the Implementation Process
#
#
#
# 11
# 2023 – Dimcon
# Project Initiation
# System Design and Configuration
# Integration
# Training and Change Management
# Post-Implementation Support
# Planning and Design
# Data Migration
# Testing and Quality Assurance
# Deployment and Go-Live
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
#
#
#
#
#
#
#
#
#
#
# Crafting the Framework: Our Service Architecture
#
#
#
#
#
#
#
#
# 12
# 2023 – Dimcon
#
#
#
# Excellence in Execution: Showcasing Our Business Expertise
# Accredited crew delivering proficient, successful Oracle EPM Solutions with expertise.
# Worldwide deployment across industries, fulfilling diverse Enterprise Performance Management needs.
# Small-to-medium businesses with extensive expertise in executing successful EPM projects.
# Strong customer satisfaction across Implementation, Support, Development, and Enhancement services.
# Maximized insights, precise data, empowered decision-making for stronger business outcomes.
# Reduced EPM expenses, optimized resources, faster financial closure for efficiency.
#
# 13
# 2023 – Dimcon
#
#
#
# Impactful Numbers
# Presentations are tools that can be used as lectures, speeches, reports, and more.
#
# 2021
# 100%
# 320
# 87%
# Charity
# Donate
# Volunteer
# Target
#
#
# 14
# 2023 – Dimcon
#
#
#
# Financial Services
# Food and Beverages
# Higher Education
# Travel and Transportation
# Construction & Engineering
# Healthcare
# Hospitality/Restaurants
# Manufacturing
# Addressing Unique Industry Needs: Our Industry Focus
# Our reporting solutions cater to various industries, including:
#
#
#
# 15
# 2023 – Dimcon
#
#
#
#
# Expertise in Focus: A Showcase of Acquired Certifications
#
#
# 16
# 2023 – Dimcon
# Partnership Approach
#
# “A Network of Trust and Expertise”
#
# At DIMCON, we believe that partnerships are the key to unlocking innovation and driving success. We are proud to collaborate with industry-leading organizations to deliver exceptional solutions and create lasting impact.
#
#
#
#
#
#
#
# 17
# 2023 – Dimcon
#
#
#
#
#
#
#
#
#
# Celebrating Our Client Achievements
# With a decade of experience and a commitment to delivering high-quality solutions tailored to the specific needs of each client, our unique selling points set us apart as the ideal partner for organizations seeking to maximize the value of their technology investments.
# Expertise
# 24/7 Support
# Seamless Integration
# Personalised Approach
#
#
# 18
# 2023 – Dimcon
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 19
# 2023 – Dimcon
# Our Extended Family: The Clients
#
#
#
# Case Studies
#
#
# 20
# 2023 – Dimcon
#
#
# The Clear Choice:
# Why Clients Prefer DIMCON
# Expertise in delivering top-quality technology solutions
# Personalized approach to meet unique business challenges
# Seamless integration capabilities for maximum impact and success
#
#
#
#
# 21
# 2023 – Dimcon
#
#
# Our onboarding process for Oracle Cloud Financials focuses on ensuring a seamless transition to the financial management solution.
#
#
#
# Tailored Onboarding:
# DIMCON's Customized Approach
#
# 22
# 2023 – Dimcon
#
#
#
#
#
#
#
#
# 01
# 05
# 03
# 07
# 02
# 06
# 04
# 08
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Project Initiation
# Requirements Gathering and Analysis
# Testing and Quality Assurance
# Solution Design and Configuration
# Deployment and Go-Live
# Training and User Adoption
# Data Integration and Migration
# Post-Implementation Support and Optimization
#
#
# Customer Chronicles: .
# Testimonials Straight from Our Clients
# Well defined team Hierarchy with certified resources in every layer
# Global Implementations satisfying Multi-currency, statutory and Multi-Lingual requirements
# SMEs with over 15+years of experience who understands and well-defined implantation strategies
# Happy customers is all Service Areas including Implementations, Support, Development and Extensions
# Increased Profitability, Advanced Reporting Capabilities, Streamlined Month-End Processing and Established Security Controls
# Reduced Maintenance Costs; Decreased Wait Times with readily available analytics
#
#
#
# 23
# 2023 – Dimcon
#
# info@dimcon.com
# 703-636-0933
# www.dimcon.com
# If you have any questions or concerns, we are here to help.
# CONTACT US
#
#
#
#
#
#
# 24
# 2023 – Dimcon
#
#
#
#
#
#
# Thank You !
# For considering DIMCON. We appreciate your time and attention.
# 2023 – Dimcon
